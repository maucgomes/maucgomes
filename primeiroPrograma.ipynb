# %% [markdown]
# <a href="https://colab.research.google.com/github/maucgomes/maucgomes/blob/main/primeiroPrograma.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from ast import main
#Funçao para exibir o nome
def exibir_nome():
  nome = input('Digite seu nome: ') #Receber seu nome
  print(nome)

#Modulo Principal
if __name__ == '__main__':
  exibir_nome()
# Out:
# Digite seu nome: Teste
# Teste
